# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from skimage import io

from skimage.measure import label

# %%
def plot_img(img, cmap='gray'):
    plt.figure(figsize=(10, 10))
    plt.imshow(img, cmap=cmap)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Image

# %%
img = np.load('lungs_0.npy')

print(f'min HU value = {img.min()}; max HU value = {img.max()}')

plot_img(img)
# Out:
# min HU value = -1024; max HU value = 1442

# %% [markdown]
# You can read about Hounsfield units (HU) [here](https://en.wikipedia.org/wiki/Hounsfield_scale).
#
# tldr; you need only values from the table **Substance** -- **HU**.
#
# Basically, the first step is to create the binary mask for the "air" pixels,
# i.e., to separate the air from the soft tissues (and other objects with even higher HU values).

# %% [markdown]
# ## Task

# %% [markdown]
# The goal is to create a binary mask for lungs. The mask should capture the air in lungs as well as most of the vessels and bronchi.
#
# Example of the output is given below.

# %% [markdown]
# ## Solution

# %%
 # normalisation
img_norm = cv2.normalize(img, 0, 255, norm_type=cv2.NORM_L2)
print('BRUH')
plot_img(img_norm)
# Out:
# BRUH

# %%
img_air = cv2.inRange(img, -1000, img.max())
plot_img(img_air)

# %%
def get_lungs_mask(img):
    raise NotImplementedError
    
    
res = get_lungs_mask(img)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /home/dendav/projects/Intro2CV_course/Lecture 3: binary images/lecture3_exercise2_lungs_mask.ipynb Cell 12 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/dendav/projects/Intro2CV_course/Lecture%203%3A%20binary%20images/lecture3_exercise2_lungs_mask.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> def get_lungs_mask(img):
#       <a href='vscode-notebook-cell:/home/dendav/projects/Intro2CV_course/Lecture%203%3A%20binary%20images/lecture3_exercise2_lungs_mask.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     raise NotImplementedError
# ----> <a href='vscode-notebook-cell:/home/dendav/projects/Intro2CV_course/Lecture%203%3A%20binary%20images/lecture3_exercise2_lungs_mask.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> res = get_lungs_mask(img)
#
# /home/dendav/projects/Intro2CV_course/Lecture 3: binary images/lecture3_exercise2_lungs_mask.ipynb Cell 12 in get_lungs_mask(img)
#       <a href='vscode-notebook-cell:/home/dendav/projects/Intro2CV_course/Lecture%203%3A%20binary%20images/lecture3_exercise2_lungs_mask.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> def get_lungs_mask(img):
# ----> <a href='vscode-notebook-cell:/home/dendav/projects/Intro2CV_course/Lecture%203%3A%20binary%20images/lecture3_exercise2_lungs_mask.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     raise NotImplementedError
#
# NotImplementedError:

# %%
plot_img(res)
